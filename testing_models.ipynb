# %%
from src.models.word_embedding.simple_avg import SimpleAvg

sa = SimpleAvg(
    n_features_per_word=600,
    random_state=1,
    group_labels=True,
    min_number_per_label=1000,
    frac=1)
sa.execute_model()
# Out:
# Clean text with no words in the embedding model for index 458082 .
# Clean text with no words in the embedding model for index 326694 .
# Clean text with no words in the embedding model for index 202792 .
# Clean text with no words in the embedding model for index 45088 .
# Clean text with no words in the embedding model for index 213167 .
# Clean text with no words in the embedding model for index 288595 .
# Clean text with no words in the embedding model for index 300970 .
# Clean text with no words in the embedding model for index 443241 .
# Clean text with no words in the embedding model for index 453005 .
# Clean text with no words in the embedding model for index 401002 .
# Clean text with no words in the embedding model for index 257468 .
# Clean text with no words in the embedding model for index 234879 .
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...

# %%
from src.datasetAPI import RotaDosConcursos

rdc = RotaDosConcursos(group_labels=True)
for i in rdc.target_names:
    print(i)
#rdc = RotaDosConcursos(group_labels=True, min_number_per_label=10000)
#rdc.show_target_distribution()
# Out:
# Administração
# Administração Financeira e Orçamentária - AFO
# Administração Pública
# Agricultura/Agropecuária
# Antropologia
# Arqueologia
# Arquitetura
# Arquivologia
# Artes
# Atualidades e Conhecimentos Gerais
# Atuária / Matemática Atuária
# Auditoria
# Biblioteconomia
# Biologia
# Ciência Política
# Ciência da Computação
# Comunicação Social
# Comércio Internacional
# Conhecimentos Bancários
# Contabilidade
# Controle Externo - CEX
# Criminologia
# Dança
# Desenho Industrial
# Direito
# Economia
# Educação Física
# Enfermagem
# Engenharia (Teoria Geral)
# Engenharia Aeronáutica
# Engenharia Agronômica
# Engenharia Ambiental
# Engenharia Cartográfica e de Agrimensura
# Engenharia Civil
# Engenharia Eletrônica
# Engenharia Elétrica
# Engenharia Espacial
# Engenharia Florestal
# Engenharia Física
# Engenharia Hospitalar/Clínica
# Engenharia Industrial
# Engenharia Mecatrônica
# Engenharia Mecânica
# Engenharia Naval
# Engenharia Nuclear
# Engenharia Portuária
# ...

# %%
from src.models.rnn import RNN

rnn = RNN(
    n_features_per_word=50,
    random_state=1,
    frac=0.05,
    group_labels=True,
    min_number_per_label=1000)
rnn.execute_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 360)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 360, 50)           46748150
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 360, 128)          91648
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 360, 128)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 47)                6063
# ...

# %%
from src.models.bag_of_words.classifiers import SVM

bow = SVM(
    random_state=1)#,
    #group_labels=True,
    #min_number_per_label=1000)

bow.execute_model()
# Out:
# C:\Users\pedro\Anaconda3\envs\tf18\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Mean result 0.6299872295963779
#
#
#  Text:
#  Os resíduos sólidos de uma obra de construção civil para reciclagem resumem-se a madeira, metal, plástico e papelão. Para separar estes materiais, respectivamente, em coletores de cores (I - preto; I - vermelho; I - amarelo e IV - azul), a ordem coreta é:
#
# Expected category: Segurança e Saúde no Trabalho (Teoria e Normas)
# Prediction: Engenharia Civil
#
#
#  Text:
# ...

# %%
from src.models.bag_of_words.classifiers import SVM

bow2 = SVM(
    random_state=1,
    group_labels=True,
    min_number_per_label=1000)

bow2.execute_model()
# Out:
# C:\Users\pedro\Anaconda3\envs\tf18\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\Users\pedro\Anaconda3\envs\tf18\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# Mean result 0.6497374927354932
#
#
#  Text:
#  O distrito X pretende se desmembrar do município Y. Para iso, após a divulgação dos estudos de viabilidade municipal, apresentados e publicados na forma da lei, dependerá de
#
# Expected category: Direito
# Prediction: Legislação
#
#
#  Text:
#  Qual feramenta é utilizada para verificar um valor específico no Registro?
#
# Expected category: Ciência da Computação
# Prediction: Contabilidade
#
#
#  Text:
# ...
